# %% [markdown]
# # PHY206: General Physics for the Life Sciences II
#
# ## Tucker Knaak - Department of Physics, Creighton University - Spring 2024
#
#
# #### In Lab 3, the students investigate how virtual images are formed by both converging and diverging lenses.  The students use a diverging lens with a focal length of $f=-15$cm to view the image formed by an object placed at $5$cm, $10$cm, $15$cm, and $20$cm and then discuss their observations.  They then compare those observations to the image formed by an ojbect placed at $10$cm or $15$cm from a converging lens with a focal length of $f=20$cm.

# %% [markdown]
# #### This cell provides the class used to simulate the geometrical optics in Lab 3.

# %%
# %run PHY206_GeometricalOptics.ipynb

# %% [markdown]
# #### The following cells draw ray diagrams for both the diverging and converging lenses to compare the images formed

# %%
'''Initialize the systems'''
sys1 = geometrical_optics()
sys2 = geometrical_optics()
sys3 = geometrical_optics()
sys4 = geometrical_optics()
sys5 = geometrical_optics()

'''Add lenses and objects'''
sys1.add_lens(-15, 5)
sys2.add_lens(-15, 10)
sys3.add_lens(-15, 15)
sys4.add_lens(-15, 20)
sys5.add_lens(20, 15)

# %%
'''f = -15cm, do = 5cm'''
sys1.ray_diagram(save_diagram = True)
# Out:
# Who is the user? Tucker Knaak
# What is the filename? Lab3_RayDiagram1

# %%
'''f = -15cm, do = 10cm'''
sys2.ray_diagram(save_diagram = True)
# Out:
# Who is the user? Tucker Knaak
# What is the filename? Lab3_RayDiagram2

# %%
'''f = -15cm, do = 15cm'''
sys3.ray_diagram(save_diagram = True)
# Out:
# Who is the user? Tucker Knaak
# What is the filename? Lab3_RayDiagram3

# %%
'''f = -15cm, do = 20cm'''
sys4.ray_diagram(save_diagram = True)
# Out:
# Who is the user? Tucker Knaak
# What is the filename? Lab3_RayDiagram4

# %%
'''f = 20cm, do = 15cm'''
sys5.ray_diagram(save_diagram = True)
# Out:
# Who is the user? Tucker Knaak
# What is the filename? Lab3_RayDiagram5

# %%
'''f = -15cm, do = 15cm'''
sys3.interactive_ray_diagram()
# Out:
# interactive(children=(FloatSlider(value=-15.0, description='$f_1$ [cm]', max=5.0, min=-35.0, step=1.0), FloatS…

# %%
'''f = 20cm, do = 15cm'''
sys5.interactive_ray_diagram()
# Out:
# interactive(children=(FloatSlider(value=20.0, description='$f_1$ [cm]', max=40.0, step=1.0), FloatSlider(value…
